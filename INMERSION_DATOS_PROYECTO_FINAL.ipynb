# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesalom/InmersionDeDatos/blob/develop/INMERSION_DATOS_PROYECTO_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula 1**

# %% [markdown]
# ## Coneccion a drive y descarga de librerias

# %% [markdown]
# Conectar con  Google Drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Descarga de librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Analisis Exploratorio de los datos:

# %% [markdown]
# Lectura de los datos csv con la información de los inmuebles.

# %%
inmuebles = pd.read_csv('/content/drive/MyDrive/inmersion_datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Cambiamos el nombre de las variables que contienen tildes o caracteres especiales.

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 6172  Apartamento         Apartamento en venta en Usaquén             1
# 4337         Casa     Casa en venta en Zona Noroccidental             3
# 415   Apartamento      Apartamento en venta en Bogotá D.C             3
# 7057  Apartamento            Apartamento en venta en Bosa             2
# 729          Casa                Casa en venta en Kennedy             3
# 5870  Apartamento       Apartamento en venta en Pasadena              2
# 4467  Apartamento  Apartamento en venta en Barrios Unidos             3
# 5799         Casa                Casa en venta en Kennedy             3
# 9450         Casa                Casa en venta en Kennedy             5
# 8404  Apartamento         Apartamento en venta en Kennedy             2
#
#       Banos  Area              Barrio                                 UPZ  \
# 6172      2    66             Usaquén                             Usaquén
# ...

# %% [markdown]
# Descripcion de la información que se tiene de las diferentes variables de los inmuebles.

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Nombre de las varaibles de cada inmueble.

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Area promedio de los inmuebles (m^)

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 4497  Apartamento      Apartamento en venta en Barrios Unidos             3
# 8439  Apartamento       Apartamento en venta en Santa Barbara             2
# 4341  Apartamento      Apartamento en venta en Barrios Unidos             3
# 4040  Apartamento             Apartamento en venta en Usaquén             2
# 9309         Casa                       Casa en venta en Bosa             3
# ...           ...                                         ...           ...
# 5170  Apartamento             Apartamento en venta en Usaquén             2
# 651   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 542   Apartamento           Apartamento en venta en Chapinero             2
# 9263         Casa                       Casa en venta en Suba             3
# 6724  Apartamento  Apartamento en venta en Zona Noroccidental             3
#
# ...

# %% [markdown]
# Evaluando los inmuebles pertenecientes al barrio Chico Reservado

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# Numero de inmuebles en Chico Reservado

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %% [markdown]
# Area promedio de los inmuebles en Chico Reservado con respecto al area promedio de todos los inmuebles registrados.

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Numero de barrios de los que se tiene informacion

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %% [markdown]
# Grafico con el numero de inmuebles por barrio.

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Primeros 10 barrios con mas inmuebles de los que se tiene informacion en la base de datos

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## Desafio del Aula 1

# %% [markdown]
# 1. Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.

# %%
inmuebles_barrio_a=inmuebles[['Barrio','Area']].groupby('Barrio').mean().sort_values(by=['Area'],ascending=False).head(10)
inmuebles_barrio_a.plot(kind='bar')
plt.xlabel('Barrio')
plt.ylabel('Area promedio(m^2)')
plt.title('Top 10 barrios con inmuebles de mayor area promedio')
# Out:
# Text(0.5, 1.0, 'Top 10 barrios con inmuebles de mayor area promedio')

# %% [markdown]
# 2. Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %% [markdown]
# Datos estadisticos de los barrios con mayor numero de inmuebles.

# %%
top_barrios=inmuebles.Barrio.value_counts()[:10].index
inmuebles[['Area','Barrio']].query('Barrio in @top_barrios').groupby('Barrio').describe()
# Out:
#                       Area                                              \
#                      count        mean          std   min   25%    50%
# Barrio
# Barrios Unidos       473.0  185.621564   653.452408  28.0  62.0   87.0
# Bosa                 589.0   59.217317    59.519221  31.0  47.0   47.0
# Cedritos             554.0   96.951264    47.605022  27.0  69.0   87.0
# Chapinero            332.0  244.722892  1229.732676  15.0  70.0  110.0
# Engativa             462.0  129.454545   310.736661  21.0  54.0   71.0
# Kennedy              589.0  104.371817   100.817151  28.0  49.0   60.0
# Santa Barbara        438.0  124.869863   100.154818  30.0  66.0   89.0
# Suba                 443.0  139.085779   151.424045  34.0  62.0   88.0
# Usaquén             1105.0  134.046154   215.719357  24.0  70.0   93.0
# Zona Noroccidental   877.0  135.785633   223.813808  16.0  61.0   78.0
#
#
#                        75%      max
# Barrio
# Barrios Unidos      143.00   8884.0
# ...

# %% [markdown]
# # **Aula 2**

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 9190  Apartamento            Apartamento en venta en Engativa             2
# 4018  Apartamento      Apartamento en venta en Barrios Unidos             3
# 7974  Apartamento       Apartamento en venta en Villa Alsacia             3
# 4350  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 6211  Apartamento             Apartamento en venta en Usaquén             1
#
#       Banos  Area              Barrio                                 UPZ  \
# 9190      1    42            Engativa                            Engativá
# 4018      2   129      Barrios Unidos                           Los Andes
# 7974      2    63       Villa Alsacia         KENNEDY: Castilla + Bavaria
# 4350      1    52  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 6211      2    56             Usaquén                             Usaquén
#
#               Valor
# 9190  $ 250.000.000
# 4018  $ 560.000.000
# ...

# %% [markdown]
# ## Ajuste del formato de los datos

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# Se observo que los datos del valor de los inmuebles se encuentran como strings (cadena de caracteres).

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %% [markdown]
# Usamos la funcion split para separar la moneda del valor del inmueble.

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 4853  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8982  Apartamento     Apartamento en venta en Nueva Autopista             3
# 9216  Apartamento                Apartamento en venta en Niza             2
#
#       Banos  Area              Barrio                                 UPZ  \
# 4853      3    94  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 8982      3   105     Nueva Autopista                          Los Cedros
# 9216      1    50                Niza                                Niza
#
#               Valor Moneda       Precio
# 4853  $ 550.000.000      $  550.000.000
# 8982  $ 630.000.000      $  630.000.000
# 9216  $ 170.000.000      $  170.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Los valores de la variable precio aun se encuentran en str por el uso de punto como separador de miles.

# %%
inmuebles['Precio'].sum()
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.0
# ...

# %% [markdown]
# Se elimina el uso de punto

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Se transforma el valor de precio a flotante y se almacena en millones para facilitar el analisis

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %% [markdown]
# ## Analisis exploratorio de las variables numericas

# %% [markdown]
# Datos estadisticos de las variables numericas con las que se cuenta.

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# Revision de incosistencias

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# ## Graficos:

# %%
inmuebles['Precio_Millon'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Garficos con mayor informacion usando librerias de python

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlim((50,1500))
plt.savefig('/content/drive/MyDrive/inmersion_datos/valor_inmuebles.png',format='png')
plt.show()

# %% [markdown]
# ## Desafio del Aula 2

# %% [markdown]
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)

# %% [markdown]
# Observamos que la mayoria de los datos corresponden a inmuebles de tipo apartamento y casa.

# %%
plt.figure(figsize=(12,6))
ax1=plt.subplot(121)
ax1.bar(inmuebles.Tipo.value_counts().index,inmuebles.Tipo.value_counts())
ax1.tick_params(axis='x', rotation=90)
ax1.set_ylabel('Count')
ax1.set_xlabel('Tipo')

inmuebles_sac=inmuebles.query("Tipo not in ['Apartamento','Casa']")

ax2=plt.subplot(122)
ax2.bar(inmuebles_sac.Tipo.value_counts().index,inmuebles_sac.Tipo.value_counts())
ax2.tick_params(axis='x', rotation=90)
ax2.set_ylabel('Count')
ax2.set_xlabel('Tipo')
plt.show()
#inmuebles.query("Tipo not in ['Apartamento','Casa']").Tipo.value_counts().plot.bar()

# %% [markdown]
# Histograma del valor de los inmuebles, se observa que el valor de las casa ronda mayoritariamente los 500 millones de pesos

# %%
plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles.query("Tipo not in ['Apartamento']"),x='Precio_Millon',kde=True,hue='Tipo')
plt.xlim((50,4000))
plt.show()

# %% [markdown]
# Los otros tipos de apartamento tienen una mayor distribucion de precios pero esto puede deberse a la falta de datos.

# %%
plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles.query("Tipo in ['Oficina/Consultorio','Local','Bodega']"),x='Precio_Millon',kde=True,hue='Tipo')
plt.xlim((0,5000))
plt.show()

# %% [markdown]
# Diagrama de cajas para observar la distribucion de precios segun el tipo de apartamento.

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Tipo", y="Precio_Millon", data = inmuebles)
ax.tick_params(axis='x', rotation=45)
plt.ylim((0,5500))
plt.show()

# %% [markdown]
# 2. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %% [markdown]
# Calculamos el valor por m^2 para cada uno de los datos.

# %%
inmueblesd=inmuebles
inmueblesd['Valor_m2']=inmueblesd.Precio_Millon/inmueblesd.Area
inmueblesd.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2
# ...

# %% [markdown]
# Obtenemos el promedio del valor del metro cuadrado para cada barrio

# %%
inmueblesd_barrio=inmueblesd.groupby('Barrio').mean()
inmueblesd_barrio
# Out:
# <ipython-input-52-3c40d05ffc00>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmueblesd_barrio=inmueblesd.groupby('Barrio').mean()
#                     Habitaciones  Banos   Area  Precio_Millon  Valor_m2
# Barrio
# Alameda                     3.00   2.00  97.00         580.00      5.98
# Alhambra                    3.00   2.94 190.41         752.35      4.33
# Andes Norte                 3.00   2.86 124.86         709.57      6.05
# Antonio Nariño              4.31   2.50 163.06         459.22      3.53
# Barrancas                   2.87   2.13  70.20         314.13      4.42
# ...                          ...    ...    ...            ...       ...
# Villa Maria                 4.69   3.69 207.15         402.85      2.04
# ...

# %% [markdown]
# Obtenemos el promedio del valor de metro cuadrado como la suma de los precios entre la suma de todas las areas.

# %%
inmueblesd_barriosum=inmueblesd.groupby('Barrio').sum()
inmueblesd_barrio['Valor_m2_barrio']=inmueblesd_barriosum.Precio_Millon/inmueblesd_barriosum.Area
inmueblesd_barrio
# Out:
# <ipython-input-53-1dc54d4cb6f8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmueblesd_barriosum=inmueblesd.groupby('Barrio').sum()
#                     Habitaciones  Banos   Area  Precio_Millon  Valor_m2  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00      5.98
# Alhambra                    3.00   2.94 190.41         752.35      4.33
# Andes Norte                 3.00   2.86 124.86         709.57      6.05
# Antonio Nariño              4.31   2.50 163.06         459.22      3.53
# Barrancas                   2.87   2.13  70.20         314.13      4.42
# ...                          ...    ...    ...            ...       ...
# Villa Maria                 4.69   3.69 207.15         402.85      2.04
# ...

# %% [markdown]
# Diagrama de cajas para visualizar la distribucion del valor del metro cuadrado para los 10 barrios con mas datos

# %%
top_barrios=inmueblesd.Barrio.value_counts().head(10).index
top_barrios
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2", data = inmueblesd.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.ylim((0,12))
plt.show()

# %% [markdown]
# Diagrama de cajas para visualizar la distribucion del valor del metro segun el tipo de inmueble

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Tipo", y="Valor_m2", data = inmueblesd)
ax.tick_params(axis='x', rotation=45)
plt.ylim((0,15))
plt.show()

# %% [markdown]
# #**Aula 3**

# %%
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2  \
# 0    $ 360.000.000      $   360000000         360.00      5.14
# 1    $ 670.000.000      $   670000000         670.00      3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00      7.78
#
#    Valor_m2_Millon
# 0             5.14
# 1             3.94
# 2             7.78

# %% [markdown]
# Promedio de cada variable numerica por barrio. Se obtuvo el valor por m^2 como el promedio de los valores por m^2 de cada inmueble.

# %%
inmuebles.groupby('Barrio').mean()
# Out:
# <ipython-input-57-7fb844af9b3c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmuebles.groupby('Barrio').mean()
#                     Habitaciones  Banos   Area  Precio_Millon  Valor_m2  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00      5.98
# Alhambra                    3.00   2.94 190.41         752.35      4.33
# Andes Norte                 3.00   2.86 124.86         709.57      6.05
# Antonio Nariño              4.31   2.50 163.06         459.22      3.53
# Barrancas                   2.87   2.13  70.20         314.13      4.42
# ...                          ...    ...    ...            ...       ...
# Villa Maria                 4.69   3.69 207.15         402.85      2.04
# Villas De Granada           3.45   2.32  86.59         282.30      3.17
# ...

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
# <ipython-input-58-45bba8259daf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datos_barrio = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banos    Area  Precio_Millon  Valor_m2  \
# Barrio
# Alameda                        3      2      97         580.00      5.98
# Alhambra                      51     50    3237       12790.00     73.56
# Andes Norte                   21     20     874        4967.00     42.35
# Antonio Nariño               207    120    7827       22042.65    169.47
# Barrancas                     43     32    1053        4712.00     66.24
# ...                          ...    ...     ...            ...       ...
# Villa Maria                   61     48    2693        5237.00     26.58
# ...

# %% [markdown]
# Valor por m^2 de cada barrio calculado como la suma del valor de los inmuebles del barrio dividido por la suma de las areas de los inmuebles del mismo barrio.

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  Valor_m2  \
# Barrio
# Alameda                        3      2      97         580.00      5.98
# Alhambra                      51     50    3237       12790.00     73.56
# Andes Norte                   21     20     874        4967.00     42.35
# Antonio Nariño               207    120    7827       22042.65    169.47
# Barrancas                     43     32    1053        4712.00     66.24
# ...                          ...    ...     ...            ...       ...
# Villa Maria                   61     48    2693        5237.00     26.58
# Villas De Granada             76     51    1905        6210.62     69.71
# Villemar                      53     37    1384        5469.00     71.81
# Zona Franca                    2      1      54         160.00      2.96
# Zona Noroccidental          2778   2204  119084      544453.06   4049.16
#
#                     Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# ...

# %% [markdown]
# Se agrega el valor promedio por m^2 de cada barrio a la base de datos, para ello se transforma la variable en un diccionario y se utilizan los valores de la variables Barrio para agregar los datos en las columnas correspondientes.

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2  \
# ...

# %% [markdown]
# Top 10 barrios con mas inmuebles.

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %% [markdown]
# Para agregarles indice ya que inicialmente el indice era el nombre de los barrios

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  Valor_m2  \
# 0               Alameda             3      2      97         580.00      5.98
# 1              Alhambra            51     50    3237       12790.00     73.56
# 2           Andes Norte            21     20     874        4967.00     42.35
# 3        Antonio Nariño           207    120    7827       22042.65    169.47
# 4             Barrancas            43     32    1053        4712.00     66.24
# ..                  ...           ...    ...     ...            ...       ...
# 144         Villa Maria            61     48    2693        5237.00     26.58
# 145   Villas De Granada            76     51    1905        6210.62     69.71
# 146            Villemar            53     37    1384        5469.00     71.81
# 147         Zona Franca             2      1      54         160.00      2.96
# 148  Zona Noroccidental          2778   2204  119084      544453.06   4049.16
#
# ...

# %% [markdown]
# Visualizamos los barrios con mas inmuebles a traves de una consulta (query)

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  Valor_m2  \
# 5        Barrios Unidos          1525   1196   87799      259877.76   2070.61
# 10                 Bosa          1743    789   34879       93400.56   1654.36
# 22             Cedritos          1458   1348   53711      270027.73   2853.23
# 24            Chapinero           892    913   81248      372130.93   2466.03
# 50             Engativa          1676   1077   59808      172711.73   1795.71
# 63              Kennedy          2151   1233   61475      207963.65   2127.66
# 125       Santa Barbara          1073   1162   54693      320097.80   2701.88
# 132                Suba          1497   1202   61615      266406.04   2000.72
# 138             Usaquén          3109   3044  148121      837710.36   6334.04
# 148  Zona Noroccidental          2778   2204  119084      544453.06   4049.16
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# ...

# %% [markdown]
# ## Graficos

# %% [markdown]
# Grafico de barras del valor por m^2 en los 10 barrios con mas inmuebles

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Barrio", y="Valor_m2_Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# Grafico de cajas de la distribucion del valor por m^2 de los 10 barrios con mas inmuebles

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Igual que el grafico anterior pero limitanto los valores del eje y para una mejor visualizacion

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Grafico de cajas del are (m^2) de los 10 barrios con mas inmuebles y para areas menores de 500 m^2 para tener una mejor visualizacion.

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Grafico de cajas del pecio en millon de los 10 barrios con mas inmuebles y para precios menores de 2000 para tener una mejor visualizacion.

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# ## Variables adicionales

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Identificación (Capítulo A).csv', sep = ';',encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %% [markdown]
# Se eliminan los datos de las zonas rurales

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %% [markdown]
# Se importan el resto de los datos

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Educación (Capítulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-73-9a6daff58915>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-73-9a6daff58915>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-73-9a6daff58915>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/inmersion_datos/archivos-dane/Educación (Capítulo H).csv',sep=';',encoding='latin-1')
# ...

# %% [markdown]
# Juntamos todos los datos extraidos

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# Out:
# <ipython-input-76-94d5bdd5b9a5>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')

# %%
datos_dane.shape
# Out:
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# **Desafío**
#
# 1. Dar un vistazo a la base de datos del DANE, entender estas variables conceptualmente para entender mejor el contexto de esta base.
# 2.  Organizar tu notebook para que tu proyecto quede mejor presentado.

# %% [markdown]
# #**Aula 4**

# %% [markdown]
# Datos de Dana ya tratados

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/inmersion_datos/datos_dane.csv')
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %% [markdown]
# Se renombran las variables de la base de datos descargada.

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO',
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES',
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES',
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA',
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19',
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA',
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO',
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA',
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO',
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO',
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %% [markdown]
# Se calcula el promedio de diversas variables por UPZ (estrato).

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %% [markdown]
# En la encuesta la respuestas se almacenaron como si(1) y no(2) por lo que sustituimos todos los 2 por 0, valor mas habitual.

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %% [markdown]
# Volvemos a revisar los valores promedios para cada UPZ

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %% [markdown]
# ## Fusion de las base de datos

# %% [markdown]
# Juntamos los datos de la encuesta con la base de datos de los inmuebles a traves del nombre de las UPZ para relacionar ambas dataset.

# %%
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %% [markdown]
# Se visualizan las varibles de la base de datos junto con los datos de la encuesta.

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Valor_m2                  9520 non-null   float64
#  12  Valor_m2_Millon           9520 non-null   float64
# ...

# %% [markdown]
# Juntamos el codigo de las UPZ a la base de datos para poder trabajarlos como datos numericos. Para el join se hace por inner para que solo se cuenten los datos que se encuentren en amabas base de datos.

# %%
upz = pd.read_csv('/content/drive/MyDrive/inmersion_datos/cod_upz.csv')
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ',right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 27)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Valor_m2                  9318 non-null   float64
#  12  Valor_m2_Millon           9318 non-null   float64
# ...

# %% [markdown]
# ## Limite de datos

# %% [markdown]
# Grafico de caja de los precios de las base de datos para visualizar los datos.

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Precio_Millon')
plt.show()

# %% [markdown]
# Realizamos una consulta para normalizar el valor de los precios de la base de datos con la finalidad de entrenar mejor al modelo de machine learning.

# %%
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %% [markdown]
# Visualización de los datos despues de recortar.

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Precio_Millon')
plt.show()

# %% [markdown]
# Registramos el salario anual a partir del salario mensual.

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %% [markdown]
# ## Estudio de correlación de las variables:

# %% [markdown]
# Grafico de dispersión del valor de los inmuebles en función del salario.

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml, x='SALARIO_ANUAL_MI',y ='Valor_m2_Millon')
plt.ylim((0,15))
plt.show()

# %% [markdown]
# Calculamos el coeficiente de correlación de pearson para evaluar si existen alguna relación entre las variables del data set.

# %%
datos_ml.corr()
# Out:
# <ipython-input-97-06e284398928>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datos_ml.corr()
#                           Habitaciones  Banos  Area  Precio_Millon  Valor_m2  \
# Habitaciones                      1.00   0.44  0.03           0.18     -0.31
# Banos                             0.44   1.00  0.04           0.66     -0.03
# Area                              0.03   0.04  1.00           0.04     -0.04
# Precio_Millon                     0.18   0.66  0.04           1.00      0.36
# Valor_m2                         -0.31  -0.03 -0.04           0.36      1.00
# Valor_m2_Millon                  -0.31  -0.03 -0.04           0.36      1.00
# Valor_m2_Barrio                  -0.21   0.13 -0.04           0.40      0.49
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01           0.32      0.33
# ...

# %% [markdown]
# Diagrama de calor para visualizar mejor los valores del coeficiente de correlación.

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);
# Out:
# <ipython-input-98-eafa0665ea9a>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %% [markdown]
# ## Modelo de Machine Learning

# %% [markdown]
# Importamos la librerias para un modelo de regresión linear, para dividir la base de datos en datos de entrenamiento y datos de prueba y para evaluar los resultados obtenidos.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

# %% [markdown]
# Para este modelo se busca predecir el valor del inmueble a partir del codigo de la UPZ, relacionando la localización del inmueble con su valor. Adicionalmente se dividen los datos para hacer entrenamientos y pruebas.

# %%
X = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99)

# %%
X_train
# Out:
#       COD_UPZ_GRUPO
# 1512         817.00
# 7864          85.00
# 6058          21.00
# 1683         817.00
# 2481          14.00
# ...             ...
# 6038          21.00
# 8875         102.00
# 2200          14.00
# 3883         803.00
# 8154          85.00
#
# [6234 rows x 1 columns]

# %%
X_test
# Out:
#       COD_UPZ_GRUPO
# 6340          74.00
# 7805          85.00
# 4902          47.00
# 7041         100.00
# 2436          14.00
# ...             ...
# 3323          14.00
# 3945         803.00
# 5572          27.00
# 3633         803.00
# 3652         803.00
#
# [2079 rows x 1 columns]

# %%
y_train
# Out:
# 1512   1050.00
# 7864    129.00
# 6058    206.38
# 1683    650.00
# 2481    250.00
#          ...
# 6038    560.00
# 8875    560.00
# 2200    685.00
# 3883    850.00
# 8154    132.00
# Name: Precio_Millon, Length: 6234, dtype: float64

# %%
y_test
# Out:
# 6340   199.90
# 7805   120.80
# 4902   400.00
# 7041   340.00
# 2436   355.00
#         ...
# 3323   700.00
# 3945   510.00
# 5572   220.00
# 3633   420.00
# 3652   435.60
# Name: Precio_Millon, Length: 2079, dtype: float64

# %% [markdown]
# Creamos el modelo de regresion lineal

# %%
modelo = LinearRegression()

# %% [markdown]
# Ajustamos el modelo con los datos de entrenamiento.

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Se realiza una predicción a partir de los datos de prueba con la finalidad de evaluar el modelo obtenido.

# %%
y_predict_test = modelo.predict(X_test)

# %% [markdown]
# Evaluamos el error absoluto medio y el coeficiente de determinación R^2 para validar el modelo.

# %%
baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
print(baseline_mae,baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %% [markdown]
# Se crea otro modelo agragando mas variables.

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']]

y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %% [markdown]
# Se realiza una prueba para obtener el valor aproximado de un inmuble con las siguientes caracteristicas:
# * Codigo UPZ: 816.
# * N de habitaciones:3.
# * N de baños: 2.
# * Conjunto Cerrado: si (1).
# * Salario anual: 50 millones.
# * Tiene escritura: si (1).

# %%
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])

# %% [markdown]
# ## Desafio del Aula 4

# %% [markdown]
# 1. Probar otros Modelos de Machine Learning

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, x = 'Habitaciones',y='Precio_Millon')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, x = 'Banos',y = 'Precio_Millon')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, x = 'Area',y = 'Precio_Millon')
plt.show()

# %% [markdown]
# 2. Trabajar con los datos y probar nuevas variables
